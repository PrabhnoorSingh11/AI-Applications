# %% [markdown]
# Lab 2 _ Pandas exercise

# %%
import pandas as pd

# %% [markdown]
# from the salaries dataset from kaggle
#
# https://www.kaggle.com/datasets/kaggle/sf-salaries
#
# 1) Read Salaries.csv as a dataframe called sal.

# %%
# a dataframe
sal = pd.read_csv("Salaries.csv")
 
sal
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 40404  40405        David Parry
# 40405  40406       Francisco Ho
# 40406  40407    Manuel Gonzales
# 40407  40408     Lauro Baca III
# 40408  40409    Milagros Brosas
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %% [markdown]
# 2) Check the head of the DataFrame

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#      Year  Notes         Agency  Status
# ...

# %% [markdown]
# 3) Use the .info() method to find out how many entries there are

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40409 entries, 0 to 40408
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                40409 non-null  int64
#  1   EmployeeName      40409 non-null  object
#  2   JobTitle          40409 non-null  object
#  3   BasePay           40408 non-null  float64
#  4   OvertimePay       40408 non-null  float64
#  5   OtherPay          40408 non-null  float64
#  6   Benefits          4249 non-null   float64
#  7   TotalPay          40408 non-null  float64
#  8   TotalPayBenefits  40408 non-null  float64
#  9   Year              40408 non-null  float64
#  10  Notes             0 non-null      float64
#  11  Agency            40408 non-null  object
#  12  Status            0 non-null      float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 4.0+ MB

# %% [markdown]
# 4) What is the average BasePay ?

# %%
b= sal
b['BasePay'].mean()
# Out:
# 71096.6857775688

# %% [markdown]
# 5) What is the highest amount of OvertimePay in the dataset ?

# %%
# hm = sal.select_dtypes(include=float, exclude=str)
# i = hm.max(numeric_only=True)
# i
hm = sal
hm['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# 6) what is the job title of JOSEPH DRISCOLL ? ( use all caps )

# %% [markdown]
# 7) How Much does JD make ( including benefits ) ?

# %% [markdown]
# 8) What is the name of the highest paid person ( including benefits ) ?

# %%
#sal['EmployeeName'][sal['TotalPayBenefits'].max()]

sal['TotalPayBenefits'].max()
# Out:
# 567595.43

# %% [markdown]
# 9) What is the name of the lowest paid person ( including benefits ) ?

# %%
sal['TotalPayBenefits'].min()
# Out:
# 0.0

# %%
sal
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 40404  40405        David Parry
# 40405  40406       Francisco Ho
# 40406  40407    Manuel Gonzales
# 40407  40408     Lauro Baca III
# 40408  40409    Milagros Brosas
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %% [markdown]
# 10) What was the average(mean) BasePay of all employess per year ? ( 2011-14)

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()

# sal['Year'] = le.fit_transform(sal['Year'].astype(float))
# sal[ 'Year' < 2014.0]

# %% [markdown]
# 11) How many unique job titles are there ?

# %% [markdown]
# 12) What are the top 5 most common jobs ?

# %% [markdown]
# 13) How many job titles were represented by only one person in 2013 ? ( e.g. Job Titles with only one occurrence in 2013? )

# %% [markdown]
# 14) How many people have the word Chief in their job title ?

# %%
# sal['JobTitle'=='CHIEF']

# %% [markdown]
# 15) Is there a correlation between length of the Job Title string and Salary ?
